# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-Vega18/-ANALISIS-EXPLOR-DE-DATOS---63510/blob/main/Taller_clase_2_marzo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/mnt/drive')
import os
import pandas as pd
# Out:
# Drive already mounted at /mnt/drive; to attempt to forcibly remount, call drive.mount("/mnt/drive", force_remount=True).

# %%
os.getcwd()
#os.listdir()
os.chdir('/mnt/drive/MyDrive/ciencia_de_datos')
os.listdir()
# Out:
# ['netflix_data.csv', 'democracy_data.csv']

# %%
df = pd.read_csv('democracy_data.csv')
df
# Out:
#        Unnamed: 0 country_name country_code  year  regime_category_index  \
# 0               1  Afghanistan          AFG  1950                    5.0
# 1               2  Afghanistan          AFG  1951                    5.0
# 2               3  Afghanistan          AFG  1952                    5.0
# 3               4  Afghanistan          AFG  1953                    5.0
# 4               5  Afghanistan          AFG  1954                    5.0
# ...           ...          ...          ...   ...                    ...
# 14763       14764     Zimbabwe          ZWE  2016                    3.0
# 14764       14765     Zimbabwe          ZWE  2017                    3.0
# 14765       14766     Zimbabwe          ZWE  2018                    4.0
# 14766       14767     Zimbabwe          ZWE  2019                    4.0
# 14767       14768     Zimbabwe          ZWE  2020                    4.0
#
#              regime_category is_monarchy is_commonwealth         monarch_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14768 entries, 0 to 14767
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   14768 non-null  int64
#  1   country_name                 14768 non-null  object
#  2   country_code                 14768 non-null  object
#  3   year                         14768 non-null  int64
#  4   regime_category_index        11291 non-null  float64
#  5   regime_category              14767 non-null  object
#  6   is_monarchy                  14554 non-null  object
#  7   is_commonwealth              14625 non-null  object
#  8   monarch_name                 2883 non-null   object
#  9   monarch_accession_year       2883 non-null   float64
#  10  monarch_birthyear            2741 non-null   float64
#  11  is_female_monarch            2883 non-null   object
#  12  is_democracy                 14706 non-null  object
# ...

# %%
#df['country_code'].info()
#podemos cambiar el tipo de variable, de object a category
df['colony_of'].info()
df['colony_of'].nbytes
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14768 entries, 0 to 14767
# Series name: colony_of
# Non-Null Count  Dtype
# --------------  -----
# 2560 non-null   object
# dtypes: object(1)
# memory usage: 115.5+ KB
# 118144

# %% [markdown]
# Vamos a pasar los meses de la elección a categorico.
# Primero tenemos un uso de 115.5+ KB (demasiado, curiosamente)

# %%
df['colony_of'].value_counts()
print(df['colony_of'].value_counts(normalize=True)*100)
df['colony_of'] = df['colony_of'].astype('category')
df['colony_of'].info()
# Out:
# colony_of
# United Kingdom                                       40.859375
# United States                                        11.093750
# France                                                9.609375
# Portugal                                              7.929688
# The Netherlands, part of the Netherlands Antilles     4.726562
# United Kingdom (Crown Colony)                         4.375000
# The Netherlands                                       3.593750
# US                                                    3.203125
# China                                                 1.718750
# South Africa                                          1.562500
# US (Trusteeship)                                      1.445312
# United Kingdom and France                             1.289062
# New Zealand                                           1.054688
# Netherlands                                           1.015625
# Belgium                                               1.015625
# ...

# %% [markdown]
# El peso bajó a tan solo 15.3 KB... bastante mejor.

# %% [markdown]
# RETO. Crear un diccionario de continentes y paises y luego mapear las variables a ver en que continente, se encuentran cada uno.

# %% [markdown]
# #2 PARTE
# Buscar una variable que agrupe (una categorica, como sex), y luego una
# continua para agrupar, como por ejemplo, la edad.

# %%
df.groupby('is_democracy')['lower_house_members'].agg(['mean','max', 'min'])
#df['lower_house_members']
# Out:
#                     mean     max  min
# is_democracy
# False         215.852524  2987.0  8.0
# True          149.607720   672.0  4.0

# %% [markdown]
# Llamar a SEABORN
# sns.pairplot(df)
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country_name', 'country_code', 'year',
#        'regime_category_index', 'regime_category', 'is_monarchy',
#        'is_commonwealth', 'monarch_name', 'monarch_accession_year',
#        'monarch_birthyear', 'is_female_monarch', 'is_democracy',
#        'is_presidential', 'president_name', 'president_accesion_year',
#        'president_birthyear', 'is_interim_phase', 'is_female_president',
#        'is_colony', 'colony_of', 'colony_administrated_by', 'is_communist',
#        'has_regime_change_lag', 'spatial_democracy', 'parliament_chambers',
#        'has_proportional_voting', 'election_system', 'lower_house_members',
#        'upper_house_members', 'third_house_members', 'has_new_constitution',
#        'has_full_suffrage', 'suffrage_restriction', 'electoral_category_index',
#        'electoral_category', 'spatial_electoral', 'has_alternation',
#        'is_multiparty', 'has_free_and_fair_election',
# ...

# %%
df_filter = df[['regime_category_index', "spatial_democracy", "parliament_chambers", "monarch_accession_year", "monarch_birthyear", "lower_house_members", "upper_house_members",
"third_house_members", "is_female_monarch"]]

sns.pairplot(df_filter)
plt.show()

# %%
sns.set_palette("colorblind")
sns.histplot(data=df_filter, x='monarch_accession_year', hue='is_female_monarch', kde=True)
plt.show()

# %%
sns.catplot(data=df, x ='is_monarchy', kind='count', col ='is_communist')
